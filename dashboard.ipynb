# %%
import pandas as pd
# Out:
# Running cells with '.venv (Python 3.14.2)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/mg89dva01/Documents/TD10/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
